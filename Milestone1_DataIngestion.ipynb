# %%
import requests
requests.get("https://huggingface.co").status_code
# Out:
# 200

# %%
from datasets import load_dataset
import pandas as pd

print("Starting download...")

dataset = load_dataset("sujan-maharjan/enron_email_dataset")

print("Dataset downloaded!")

df = dataset["train"].to_pandas()

print("Converted to pandas!")
df.head()
# Out:
# Starting download...
# Dataset downloaded!
# Converted to pandas!
#                                       Message_ID  \
# 0  <11736793.1075853982199.JavaMail.evans@thyme>
# 1  <21335734.1075863432077.JavaMail.evans@thyme>
# 2   <6394464.1075852096576.JavaMail.evans@thyme>
# 3  <14263320.1075842132531.JavaMail.evans@thyme>
# 4  <21007753.1075857397153.JavaMail.evans@thyme>
#
#                                     Date                         From  \
# 0  Fri, 22 Sep 2000 08:14:00 -0700 (PDT)  mkhenderson@duke-energy.com
# 1  Mon, 23 Jul 2001 12:28:33 -0700 (PDT)         j.kaminski@enron.com
# 2  Wed, 17 Oct 2001 10:51:20 -0700 (PDT)    benjamin.rogers@enron.com
# 3  Wed, 19 Jul 2000 06:09:00 -0700 (PDT)        carol.clair@enron.com
# 4  Tue, 16 Jan 2001 10:05:00 -0800 (PST)   errol.mclaughlin@enron.com
#
#                                                   To  \
# 0  dfbane@duke-energy.com, jabretz@duke-energy.co...
# 1                            pilar.ramirez@enron.com
# 2                               joe.quenet@enron.com
# 3   mark.taylor@enron.com, sara.shackleton@enron.com
# 4                          jeffrey.gossett@enron.com
#
#                            Cc                         Bcc  \
# 0                         NaN                         NaN
# 1  shirley.crenshaw@enron.com  shirley.crenshaw@enron.com
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                                              Subject  \
# 0  Revised Again: Revised: Eastrans Nomination ch...
# 1                                RE: Zone EF Meeting
# 2                                                FW:
# 3                                        Status Memo
# 4   Re: Counterparties w/ Master Agreements with ECC
#
#                                              Message
# 0  Effective 9/23/00 and continue until further n...
# 1  Pilar,\n\nI will attend.\n\n\nVince Kaminski\n\n
# 2                                              \n\n
# 3  Here is my updated status memo.\n\n\n\nCarol S...
# 4  Yes this is correct.  This is the reason Sherr...

# %%
df.shape
# Out:
# (362180, 8)

# %%
df.to_csv("enron_dataset_full.csv", index=False)

# %%
import os

print(os.getcwd())  # shows where it saved
print(os.path.getsize("enron_dataset_full.csv") / (1024 * 1024), "MB")
# Out:
# C:\Users\Anushree\Downloads\enron_kg_project
# 548.9899263381958 MB

# %%
df.to_csv("enron_dataset_full.zip", index=False, compression="zip")

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 362180 entries, 0 to 362179
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Message_ID  362180 non-null  str
#  1   Date        362180 non-null  str
#  2   From        362180 non-null  str
#  3   To          346837 non-null  str
#  4   Cc          89451 non-null   str
#  5   Bcc         89451 non-null   str
#  6   Subject     362180 non-null  str
#  7   Message     362180 non-null  str
# dtypes: str(8)
# memory usage: 565.5 MB
# Message_ID         0
# Date               0
# From               0
# To             15343
# Cc            272729
# Bcc           272729
# Subject            0
# Message            0
# dtype: int64

# %%
df['Date'] = df['Date'].str.replace(r"\(.*\)", "", regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['Date'] = df['Date'].str.replace(r"\(.*\)", "", regex=True)
#
# File ~\Downloads\enron_kg_project\venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File ~\Downloads\enron_kg_project\venv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File ~\Downloads\enron_kg_project\venv\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Downloads\enron_kg_project\venv\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError(
#     249         f"Can only use .str accessor with string values, not {inferred_dtype}"
#     250     )
#     251 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values, not datetime64

# %%
df['Date'].dtype
# Out:
# datetime64[us, UTC]

# %%
df['Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (362180, 8)

# %%
df['To'] = df['To'].fillna('')
df['Cc'] = df['Cc'].fillna('')
df['Bcc'] = df['Bcc'].fillna('')

# %%
df.isnull().sum()
# Out:
# Message_ID    0
# Date          0
# From          0
# To            0
# Cc            0
# Bcc           0
# Subject       0
# Message       0
# dtype: int64

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Hour'] = df['Date'].dt.hour

# %%
df.head()
# Out:
#                                       Message_ID                      Date  \
# 0  <11736793.1075853982199.JavaMail.evans@thyme> 2000-09-22 15:14:00+00:00
# 1  <21335734.1075863432077.JavaMail.evans@thyme> 2001-07-23 19:28:33+00:00
# 2   <6394464.1075852096576.JavaMail.evans@thyme> 2001-10-17 17:51:20+00:00
# 3  <14263320.1075842132531.JavaMail.evans@thyme> 2000-07-19 13:09:00+00:00
# 4  <21007753.1075857397153.JavaMail.evans@thyme> 2001-01-16 18:05:00+00:00
#
#                           From  \
# 0  mkhenderson@duke-energy.com
# 1         j.kaminski@enron.com
# 2    benjamin.rogers@enron.com
# 3        carol.clair@enron.com
# 4   errol.mclaughlin@enron.com
#
#                                                   To  \
# 0  dfbane@duke-energy.com, jabretz@duke-energy.co...
# 1                            pilar.ramirez@enron.com
# 2                               joe.quenet@enron.com
# 3   mark.taylor@enron.com, sara.shackleton@enron.com
# 4                          jeffrey.gossett@enron.com
#
#                            Cc                         Bcc  \
# 0
# 1  shirley.crenshaw@enron.com  shirley.crenshaw@enron.com
# 2
# 3
# 4
#
#                                              Subject  \
# 0  Revised Again: Revised: Eastrans Nomination ch...
# 1                                RE: Zone EF Meeting
# 2                                                FW:
# 3                                        Status Memo
# 4   Re: Counterparties w/ Master Agreements with ECC
#
#                                              Message  Year  Month  Day  Hour
# 0  Effective 9/23/00 and continue until further n...  2000      9   22    15
# 1  Pilar,\n\nI will attend.\n\n\nVince Kaminski\n\n   2001      7   23    19
# 2                                              \n\n   2001     10   17    17
# 3  Here is my updated status memo.\n\n\n\nCarol S...  2000      7   19    13
# 4  Yes this is correct.  This is the reason Sherr...  2001      1   16    18

# %%
df['From'] = df['From'].str.lower().str.strip()

# %%
df['From'].head()
# Out:
# 0    mkhenderson@duke-energy.com
# 1           j.kaminski@enron.com
# 2      benjamin.rogers@enron.com
# 3          carol.clair@enron.com
# 4     errol.mclaughlin@enron.com
# Name: From, dtype: str

# %%
df['To'] = df['To'].str.lower().str.strip()
df['Cc'] = df['Cc'].str.lower().str.strip()
df['Bcc'] = df['Bcc'].str.lower().str.strip()

# %%
df[['To', 'Cc', 'Bcc']].head()
# Out:
#                                                   To  \
# 0  dfbane@duke-energy.com, jabretz@duke-energy.co...
# 1                            pilar.ramirez@enron.com
# 2                               joe.quenet@enron.com
# 3   mark.taylor@enron.com, sara.shackleton@enron.com
# 4                          jeffrey.gossett@enron.com
#
#                            Cc                         Bcc
# 0
# 1  shirley.crenshaw@enron.com  shirley.crenshaw@enron.com
# 2
# 3
# 4

# %%
df['To'] = df['To'].apply(lambda x: [email.strip() for email in x.split(',')] if x else [])
df['Cc'] = df['Cc'].apply(lambda x: [email.strip() for email in x.split(',')] if x else [])
df['Bcc'] = df['Bcc'].apply(lambda x: [email.strip() for email in x.split(',')] if x else [])

# %%
df[['To','Cc','Bcc']].head()
# Out:
#                                                   To  \
# 0  [dfbane@duke-energy.com, jabretz@duke-energy.c...
# 1                          [pilar.ramirez@enron.com]
# 2                             [joe.quenet@enron.com]
# 3  [mark.taylor@enron.com, sara.shackleton@enron....
# 4                        [jeffrey.gossett@enron.com]
#
#                              Cc                           Bcc
# 0                            []                            []
# 1  [shirley.crenshaw@enron.com]  [shirley.crenshaw@enron.com]
# 2                            []                            []
# 3                            []                            []
# 4                            []                            []

# %%
df_exploded = df.explode('To')

# %%
df_exploded[['From','To']].head(10)
# Out:
#                           From                            To
# 0  mkhenderson@duke-energy.com        dfbane@duke-energy.com
# 0  mkhenderson@duke-energy.com       jabretz@duke-energy.com
# 0  mkhenderson@duke-energy.com        cwcass@duke-energy.com
# 0  mkhenderson@duke-energy.com      mrcherry@duke-energy.com
# 0  mkhenderson@duke-energy.com    wespeckels@duke-energy.com
# 0  mkhenderson@duke-energy.com     dcspencer@duke-energy.com
# 0  mkhenderson@duke-energy.com     jaurbanek@duke-energy.com
# 0  mkhenderson@duke-energy.com              briley@enron.com
# 0  mkhenderson@duke-energy.com             dfarmer@enron.com
# 0  mkhenderson@duke-energy.com  carlos.j.rodriguez@enron.com

# %%
df_exploded.shape
# Out:
# (2189693, 12)

# %%
edges = df_exploded[['From', 'To', 'Date', 'Year', 'Month', 'Hour']]

# %%
edges.head()
edges.shape
# Out:
# (2189693, 6)

# %%
comm_freq = edges.groupby(['From', 'To']).size().reset_index(name='Email_Count')

# %%
comm_freq.head()
comm_freq.shape
# Out:
# (280853, 3)

# %%
sample_edges = comm_freq.sort_values(by='Email_Count', ascending=False).head(100)

# %%
sample_edges.head()
# Out:
#                             From                         To  Email_Count
# 205161      pete.davis@enron.com       pete.davis@enron.com         6414
# 275851  vince.kaminski@enron.com          vkaminski@aol.com         3056
# 111661   jeff.dasovich@enron.com  richard.shapiro@enron.com         2042
# 111611   jeff.dasovich@enron.com     paul.kaufman@enron.com         1958
# 111312   jeff.dasovich@enron.com    james.steffes@enron.com         1924

# %%
comm_freq = comm_freq[comm_freq['From'] != comm_freq['To']]

# %%
sample_edges = comm_freq.sort_values(by='Email_Count', ascending=False).head(100)
sample_edges.head()
# Out:
#                             From                         To  Email_Count
# 275851  vince.kaminski@enron.com          vkaminski@aol.com         3056
# 111661   jeff.dasovich@enron.com  richard.shapiro@enron.com         2042
# 111611   jeff.dasovich@enron.com     paul.kaufman@enron.com         1958
# 111312   jeff.dasovich@enron.com    james.steffes@enron.com         1924
# 111787   jeff.dasovich@enron.com       susan.mara@enron.com         1921

# %%
sample_edges.to_csv("sample_edges.csv", index=False)

# %%
#an API that exposes structured communication insights-- FLASK API MAKING REMAININGG

# %%
# Collect unique persons from From and To
persons = pd.concat([df_exploded['From'], df_exploded['To']]).unique()

person_nodes = pd.DataFrame(persons, columns=['email'])

person_nodes.head()
# Out:
#                          email
# 0  mkhenderson@duke-energy.com
# 1         j.kaminski@enron.com
# 2    benjamin.rogers@enron.com
# 3        carol.clair@enron.com
# 4   errol.mclaughlin@enron.com

# %%
email_nodes = df[['Message_ID', 'Subject', 'Date', 'Year', 'Month', 'Hour']].drop_duplicates()

email_nodes.head()
# Out:
#                                       Message_ID  \
# 0  <11736793.1075853982199.JavaMail.evans@thyme>
# 1  <21335734.1075863432077.JavaMail.evans@thyme>
# 2   <6394464.1075852096576.JavaMail.evans@thyme>
# 3  <14263320.1075842132531.JavaMail.evans@thyme>
# 4  <21007753.1075857397153.JavaMail.evans@thyme>
#
#                                              Subject  \
# 0  Revised Again: Revised: Eastrans Nomination ch...
# 1                                RE: Zone EF Meeting
# 2                                                FW:
# 3                                        Status Memo
# 4   Re: Counterparties w/ Master Agreements with ECC
#
#                        Date  Year  Month  Hour
# 0 2000-09-22 15:14:00+00:00  2000      9    15
# 1 2001-07-23 19:28:33+00:00  2001      7    19
# 2 2001-10-17 17:51:20+00:00  2001     10    17
# 3 2000-07-19 13:09:00+00:00  2000      7    13
# 4 2001-01-16 18:05:00+00:00  2001      1    18

# %%
sent_rel = df[['From', 'Message_ID']].drop_duplicates()

sent_rel.head()
# Out:
#                           From                                     Message_ID
# 0  mkhenderson@duke-energy.com  <11736793.1075853982199.JavaMail.evans@thyme>
# 1         j.kaminski@enron.com  <21335734.1075863432077.JavaMail.evans@thyme>
# 2    benjamin.rogers@enron.com   <6394464.1075852096576.JavaMail.evans@thyme>
# 3        carol.clair@enron.com  <14263320.1075842132531.JavaMail.evans@thyme>
# 4   errol.mclaughlin@enron.com  <21007753.1075857397153.JavaMail.evans@thyme>

# %%
sent_to_rel = df_exploded[['Message_ID', 'To']].drop_duplicates()

sent_to_rel.head()
# Out:
#                                       Message_ID                          To
# 0  <11736793.1075853982199.JavaMail.evans@thyme>      dfbane@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>     jabretz@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>      cwcass@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>    mrcherry@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>  wespeckels@duke-energy.com

# %%
person_nodes['cypher'] = person_nodes['email'].apply(
    lambda x: f'CREATE (:Person {{email: "{x}"}});'
)

person_nodes['cypher'].head()
# Out:
# 0    CREATE (:Person {email: "mkhenderson@duke-ener...
# 1    CREATE (:Person {email: "j.kaminski@enron.com"});
# 2    CREATE (:Person {email: "benjamin.rogers@enron...
# 3    CREATE (:Person {email: "carol.clair@enron.com...
# 4    CREATE (:Person {email: "errol.mclaughlin@enro...
# Name: cypher, dtype: str

# %%
email_nodes['cypher'] = email_nodes.apply(
    lambda row: f'CREATE (:Email {{message_id: "{row["Message_ID"]}", '
                f'subject: "{str(row["Subject"]).replace("\"","")}", '
                f'date: "{row["Date"]}", '
                f'year: {row["Year"]}, '
                f'month: {row["Month"]}, '
                f'hour: {row["Hour"]}}});',
    axis=1
)

email_nodes['cypher'].head()
# Out:
# 0    CREATE (:Email {message_id: "<11736793.1075853...
# 1    CREATE (:Email {message_id: "<21335734.1075863...
# 2    CREATE (:Email {message_id: "<6394464.10758520...
# 3    CREATE (:Email {message_id: "<14263320.1075842...
# 4    CREATE (:Email {message_id: "<21007753.1075857...
# Name: cypher, dtype: str

# %%
sent_rel['cypher'] = sent_rel.apply(
    lambda row: f'''
MATCH (p:Person {{email: "{row["From"]}"}})
MATCH (e:Email {{message_id: "{row["Message_ID"]}"}})
CREATE (p)-[:SENT]->(e);
''',
    axis=1
)

sent_rel['cypher'].head()
# Out:
# 0    \nMATCH (p:Person {email: "mkhenderson@duke-en...
# 1    \nMATCH (p:Person {email: "j.kaminski@enron.co...
# 2    \nMATCH (p:Person {email: "benjamin.rogers@enr...
# 3    \nMATCH (p:Person {email: "carol.clair@enron.c...
# 4    \nMATCH (p:Person {email: "errol.mclaughlin@en...
# Name: cypher, dtype: str

# %%
sent_to_rel['cypher'] = sent_to_rel.apply(
    lambda row: f'''
MATCH (e:Email {{message_id: "{row["Message_ID"]}"}})
MATCH (p:Person {{email: "{row["To"]}"}})
CREATE (e)-[:SENT_TO]->(p);
''',
    axis=1
)

sent_to_rel['cypher'].head()

# %%
sent_to_sample = sent_to_rel.head(5000)

# %%
sent_to_sample['cypher'] = (
    'MATCH (e:Email {message_id: "' + sent_to_sample['Message_ID'] +
    '"}) MATCH (p:Person {email: "' + sent_to_sample['To'] +
    '"}) CREATE (e)-[:SENT_TO]->(p);'
)

# %%
sent_to_sample[['Message_ID', 'To', 'cypher']].head()
# Out:
#                                       Message_ID                          To  \
# 0  <11736793.1075853982199.JavaMail.evans@thyme>      dfbane@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>     jabretz@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>      cwcass@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>    mrcherry@duke-energy.com
# 0  <11736793.1075853982199.JavaMail.evans@thyme>  wespeckels@duke-energy.com
#
#                                               cypher
# 0  MATCH (e:Email {message_id: "<11736793.1075853...
# 0  MATCH (e:Email {message_id: "<11736793.1075853...
# 0  MATCH (e:Email {message_id: "<11736793.1075853...
# 0  MATCH (e:Email {message_id: "<11736793.1075853...
# 0  MATCH (e:Email {message_id: "<11736793.1075853...

# %%
person_nodes['domain'] = person_nodes['email'].str.split('@').str[1]

org_nodes = person_nodes[['domain']].drop_duplicates().rename(columns={'domain': 'name'})

org_nodes.head()
# Out:
#                name
# 0   duke-energy.com
# 1         enron.com
# 27    scientech.com
# 29       enron.com>
# 31          aol.com

# %%
org_nodes['cypher'] = org_nodes['name'].apply(
    lambda x: f'CREATE (:Organization {{name: "{x}"}});'
)

org_nodes.head()
# Out:
#                name                                             cypher
# 0   duke-energy.com  CREATE (:Organization {name: "duke-energy.com"});
# 1         enron.com        CREATE (:Organization {name: "enron.com"});
# 27    scientech.com    CREATE (:Organization {name: "scientech.com"});
# 29       enron.com>       CREATE (:Organization {name: "enron.com>"});
# 31          aol.com          CREATE (:Organization {name: "aol.com"});

# %%
works_at_rel = person_nodes[['email', 'domain']]

works_at_rel['cypher'] = (
    'MATCH (p:Person {email: "' + works_at_rel['email'] +
    '"}) MATCH (o:Organization {name: "' + works_at_rel['domain'] +
    '"}) CREATE (p)-[:WORKS_AT]->(o);'
)

works_at_rel.head()
# Out:
#                          email           domain  \
# 0  mkhenderson@duke-energy.com  duke-energy.com
# 1         j.kaminski@enron.com        enron.com
# 2    benjamin.rogers@enron.com        enron.com
# 3        carol.clair@enron.com        enron.com
# 4   errol.mclaughlin@enron.com        enron.com
#
#                                               cypher
# 0  MATCH (p:Person {email: "mkhenderson@duke-ener...
# 1  MATCH (p:Person {email: "j.kaminski@enron.com"...
# 2  MATCH (p:Person {email: "benjamin.rogers@enron...
# 3  MATCH (p:Person {email: "carol.clair@enron.com...
# 4  MATCH (p:Person {email: "errol.mclaughlin@enro...

# %%
all_cypher = pd.concat([
    person_nodes['cypher'],
    org_nodes['cypher'],
    email_nodes.head(5000)['cypher'],   # sample for speed
    sent_rel.head(5000)['cypher'],
    sent_to_sample['cypher'],
    works_at_rel.head(5000)['cypher']
])

all_cypher.to_csv("enron_kg_script.cypher", index=False, header=False)

# %%
# !pip install networkx matplotlib
# Out:
# Collecting networkx
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\anushree\downloads\enron_kg_project\venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\anushree\downloads\enron_kg_project\venv\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anushree\downloads\enron_kg_project\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anushree\downloads\enron_kg_project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 5.6 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 2.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.1 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.9 MB/s eta 0:00:00
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 8.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.1 MB 2.4 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.1 MB 2.5 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.6 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 1.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.5 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/7.0 MB 1.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.0 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.4 MB/s eta 0:00:05
#    -------- ------------------------------- 1.6/7.0 MB 1.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.0 MB 1.5 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.0 MB 1.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/7.0 MB 1.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.1/7.0 MB 1.7 MB/s eta 0:00:03
#    -------------------- ------------------- 3.7/7.0 MB 1.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.6 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, networkx, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 networkx-3.6.1 pillow-12.1.1 pyparsing-3.3.2
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create directed graph
G = nx.DiGraph()

# Add edges from sample_edges
for _, row in sample_edges.head(50).iterrows():
    G.add_edge(row['From'], row['To'], weight=row['Email_Count'])

# Draw graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.5)

nx.draw(G, pos, with_labels=False, node_size=300, arrows=True)
plt.title("Enron Communication Subgraph")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create directed graph
G = nx.DiGraph()

# Add edges from sample_edges
for _, row in sample_edges.head(50).iterrows():
    G.add_edge(row['From'], row['To'], weight=row['Email_Count'])

# Draw graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.5)

nx.draw_networkx(G, pos, node_size=400, font_size=6)
plt.title("Enron Communication Subgraph")
plt.show()

# %%
degree_centrality = nx.degree_centrality(G)

top_senders = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]

for email, score in top_senders:
    print(email, round(score, 4))
# Out:
# jeff.dasovich@enron.com 0.7037
# susan.mara@enron.com 0.0556
# mjones7@txu.com 0.0556
# vince.kaminski@enron.com 0.037
# richard.shapiro@enron.com 0.037
# enron.announcements@enron.com 0.037
# kay.mann@enron.com 0.037
# vkaminski@aol.com 0.0185
# paul.kaufman@enron.com 0.0185
# james.steffes@enron.com 0.0185

# %%
in_degree = G.in_degree()

top_receivers = sorted(in_degree, key=lambda x: x[1], reverse=True)[:10]

for email, count in top_receivers:
    print(email, count)
# Out:
# richard.shapiro@enron.com 2
# vkaminski@aol.com 1
# jeff.dasovich@enron.com 1
# paul.kaufman@enron.com 1
# james.steffes@enron.com 1
# susan.mara@enron.com 1
# karen.denne@enron.com 1
# skean@enron.com 1
# all.worldwide@enron.com 1
# recipients@enron.com 1

# %%
out_degree = G.out_degree()

top_senders = sorted(out_degree, key=lambda x: x[1], reverse=True)[:10]

for email, count in top_senders:
    print(email, count)
# Out:
# jeff.dasovich@enron.com 37
# mjones7@txu.com 3
# vince.kaminski@enron.com 2
# susan.mara@enron.com 2
# enron.announcements@enron.com 2
# kay.mann@enron.com 2
# veronica.espinoza@enron.com 1
# steven.kean@enron.com 1
# vkaminski@aol.com 0
# richard.shapiro@enron.com 0

# %%
components = list(nx.weakly_connected_components(G))

largest_cluster = max(components, key=len)

print("Largest cluster size:", len(largest_cluster))
# Out:
# Largest cluster size: 38
